# %%
# !make && time ./a.out sharpin5.txt out.txt > temperatures_evolution.txt 2> energy_evolution.txt
# Out:
# g++ -std=c++17 *.cc
#
# real	0m19,328s
# user	0m19,300s
# sys	0m0,012s

# %%
# !g++ -std=c++17 -Ofast *.cc

# %%
# !time ./a.out sharpin6.txt out.txt
# Out:
# real	12m32,202s
# user	12m31,493s
# sys	0m0,068s

# %%
from matplotlib import pyplot as plt
with open("temperatures_evolution.txt") as f:
    s = f.readline()
# pop last ','   
s = '[' + s[:-1] + ']'

l = eval(s)

plt.plot(l, label="λ=0.9999, T_0=1, i=10000, T_x=1")
plt.legend()
plt.title("Tetravex 5x5")
plt.xlabel("Nombre d'iterations")
plt.ylabel("Température")
plt.show()

# %%
with open("energy_evolution.txt") as f:
    s = f.readline()
# pop last ','   
s = '[' + s[:-1] + ']'

l = eval(s)

plt.plot(l, label="λ=0.9999, T_0=1, i=10000, T_x=1")
plt.legend()
plt.title("Tetravex 5x5")
plt.xlabel("Nombre d'iterations")
plt.ylabel("Energie")
plt.show()
